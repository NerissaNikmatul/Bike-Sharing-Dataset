# %% [markdown]
# # **Proyek Analisis Data: Bike Sharing Dataset**
# - Nama : Nerissa Nikmatul Qoiriyah
# - Email: nerissankmtul@gmail.com
# - Id Dicoding: nerissa_nikmatul

# %% [markdown]
# ## **Menentukan Pertanyaan Bisnis**

# %% [markdown]
# - Apakah cuaca mempengaruhi jumlah orang yang menggunakan sepeda?
# - Bagaimana perbedaan penggunaan sepeda pada hari kerja, hari libur, dan hari biasa?

# %% [markdown]
# ## **Menyiapkan library yang dibutuhkan**

# %% [markdown]
# Sebelum memulai proyek, memastika sudah mengimport semua library yang dibutuhkan untuk mengerjakan proyek.

# %%
# memanggil library yang dibutuhkan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## **Data Wrangling**

# %% [markdown]
# ### **Gathering Data**

# %% [markdown]
# Pada tahap ini yaitu mengumpulkan data yang telah dikumpulkan.

# %% [markdown]
# ### **Load tabel day**

# %%
day_df = pd.read_csv("https://raw.githubusercontent.com/NerissaNikmatul/Bike-Sharing-Dataset/refs/heads/main/data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### **Load tabel hr**

# %%
hr_df = pd.read_csv("https://raw.githubusercontent.com/NerissaNikmatul/Bike-Sharing-Dataset/refs/heads/main/data/hour.csv")
hr_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ### **Menilai day_df**

# %% [markdown]
# 1. Cek tipe data day_df

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Terdapat 1 tipe data berdasarkan kolomnya yang tidak sesuai. Data yang perlu diperbaiki adalah: dteday -> datetime

# %% [markdown]
# 2. Cek apakah ada missing values

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Kesimpulan bahwa tabel day_df tidak ada missing values, dan aman.

# %% [markdown]
# 3. Cek apakah ada duplicate data

# %%
print("Jumlah duplikasi data: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi data:  0

# %% [markdown]
# Pada tabel day_df terdapat 0 data yang double, jadi semua data bersifat unik.

# %% [markdown]
# 4. Cek apakah terdapat keanehan pada nilai statistiknya

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# Tidak ada keanehan pada nilai statistiknya.

# %% [markdown]
# ### **Menilai hr_df**

# %% [markdown]
# 1. Cek info hr_df

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# Terdapat 1 tipe data berdasarkan kolomnya yang tidak sesuai. Data yang perlu diperbaiki adalah: dteday -> datetime

# %% [markdown]
# 2. Cek apakah ada missing values

# %%
hr_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# kesimpulan bahwa tabel hr_df tidak ada missing values, dan aman.

# %% [markdown]
# 3. Cek apakah ada duplicate data

# %%
print("Jumlah duplikasi data: ", hr_df.duplicated().sum())
# Out:
# Jumlah duplikasi data:  0

# %% [markdown]
# 4. Cek apakah terdapat keanehan pada nilai statistiknya

# %%
hr_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# Tidak ada keanehan pada nilai statistiknya.

# %% [markdown]
# ### **Cleaning Data**

# %% [markdown]
# 1. Menghapus tabel yang tidak diperlukan
#
# Sebelum melanjutkan ke langkah berikutnya, menghapus tabel **hr** terlebih dahulu. Hal ini dilakukan karena tabel tersebut tidak relevan dengan pertanyaan bisnis yang telah ditetapkan. Selain itu, tabel **hr** pada dasarnya hanya berbeda pada kolom **hr**, sementara sisanya hampir sama dengan tabel **day**.

# %%
del hr_df

# %% [markdown]
# 2. Menghapus beberapa kolom yang tidak akan digunakan
#
# Berdasarkan pertanyaan bisnis yang sudah ada, maka untuk kolom yang akan didrop, yakni:
# - instant: Karena indeks catatan ini tidak memberikan informasi tambahan yang berguna.
# - windspeed: Tidak ada pertanyaan bisnis yang terkait dengan efek kecepatan angin terhadap jumlah penyewa sepeda.

# %%
drop_col = ['instant', 'windspeed']

for i in day_df.columns:
  if i in drop_col:
    day_df.drop(labels=i, axis=1, inplace=True)

day_df.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        temp     atemp       hum  casual  registered   cnt
# 0  0.344167  0.363625  0.805833     331         654   985
# 1  0.363478  0.353739  0.696087     131         670   801
# 2  0.196364  0.189405  0.437273     120        1229  1349
# 3  0.200000  0.212122  0.590435     108        1454  1562
# 4  0.226957  0.229270  0.436957      82        1518  1600

# %% [markdown]
# 3. Mengubah beberapa detail tentang kolom
#
# Karena nama-nama kolom di atas kurang sesuai dengan gaya saya, maka akan saya ubah. Saya juga lebih menyukai tipe data kategorikal, jadi beberapa yang sebelumnya angka akan diubah. Selain itu, ada tipe data yang tidak sesuai dan akan saya sesuaikan.

# %%
# Mengubah nama judul kolom
day_df.rename(columns={
    'dteday': 'dateday',
    'yr': 'year',
    'mnth': 'month',
    'weathersit': 'weather_cond',
    'cnt': 'count'
}, inplace=True)

day_df.head()
# Out:
#       dateday  season  year  month  holiday  weekday  workingday  \
# 0  2011-01-01       1     0      1        0        6           0
# 1  2011-01-02       1     0      1        0        0           0
# 2  2011-01-03       1     0      1        0        1           1
# 3  2011-01-04       1     0      1        0        2           1
# 4  2011-01-05       1     0      1        0        3           1
#
#    weather_cond      temp     atemp       hum  casual  registered  count
# 0             2  0.344167  0.363625  0.805833     331         654    985
# 1             2  0.363478  0.353739  0.696087     131         670    801
# 2             1  0.196364  0.189405  0.437273     120        1229   1349
# 3             1  0.200000  0.212122  0.590435     108        1454   1562
# 4             1  0.226957  0.229270  0.436957      82        1518   1600

# %%
# Mengubah angka menjadi keterangan
day_df['month'] = day_df['month'].map({
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
    7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
})
day_df['season'] = day_df['season'].map({
    1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'
})
day_df['weekday'] = day_df['weekday'].map({
    0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'
})
day_df['weather_cond'] = day_df['weather_cond'].map({
    1: 'Clear/Partly Cloudy',
    2: 'Misty/Cloudy',
    3: 'Light Snow/Rain',
    4: 'Severe Weather'
})

# %%
# Mengubah tipe data ke datetime
day_df['dateday'] = pd.to_datetime(day_df.dateday)

# Mengubaha tipe data ke categorical
day_df['season'] = day_df.season.astype('category')
day_df['year'] = day_df.year.astype('category')
day_df['month'] = day_df.month.astype('category')
day_df['holiday'] = day_df.holiday.astype('category')
day_df['weekday'] = day_df.weekday.astype('category')
day_df['workingday'] = day_df.workingday.astype('category')
day_df['weather_cond'] = day_df.weather_cond.astype('category')

day_df.head()
# Out:
#      dateday  season year month holiday weekday workingday  \
# 0 2011-01-01  Spring    0   Jan       0     Sat          0
# 1 2011-01-02  Spring    0   Jan       0     Sun          0
# 2 2011-01-03  Spring    0   Jan       0     Mon          1
# 3 2011-01-04  Spring    0   Jan       0     Tue          1
# 4 2011-01-05  Spring    0   Jan       0     Wed          1
#
#           weather_cond      temp     atemp       hum  casual  registered  \
# 0         Misty/Cloudy  0.344167  0.363625  0.805833     331         654
# 1         Misty/Cloudy  0.363478  0.353739  0.696087     131         670
# 2  Clear/Partly Cloudy  0.196364  0.189405  0.437273     120        1229
# 3  Clear/Partly Cloudy  0.200000  0.212122  0.590435     108        1454
# 4  Clear/Partly Cloudy  0.226957  0.229270  0.436957      82        1518
#
#    count
# 0    985
# 1    801
# 2   1349
# 3   1562
# 4   1600

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dateday       731 non-null    object
#  1   season        731 non-null    object
#  2   year          731 non-null    int64
#  3   month         731 non-null    object
#  4   holiday       731 non-null    int64
#  5   weekday       731 non-null    object
#  6   workingday    731 non-null    int64
#  7   weather_cond  731 non-null    object
#  8   temp          731 non-null    float64
#  9   atemp         731 non-null    float64
#  10  hum           731 non-null    float64
#  11  casual        731 non-null    int64
#  12  registered    731 non-null    int64
#  13  count         731 non-null    int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 80.1+ KB

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Eksplorasi Data day_df**

# %% [markdown]
# 1. Kelompok penyewaan sepeda (baik casual dan registered) berdasarkan bulan

# %%
day_df.groupby(by='month').agg({
    'count': ['max', 'min', 'mean', 'sum']
})
# Out:
#       count
#         max   min         mean     sum
# month
# Apr    7460   795  4484.900000  269094
# Aug    7865  1115  5664.419355  351194
# Dec    6606   441  3403.806452  211036
# Feb    5062  1005  2655.298246  151352
# Jan    4521   431  2176.338710  134933
# Jul    8173  3285  5563.677419  344948
# Jun    8120  3767  5772.366667  346342
# Mar    8362   605  3692.258065  228920
# May    8294  2633  5349.774194  331686
# Nov    6852  1495  4247.183333  254831
# Oct    8156    22  5199.225806  322352
# Sep    8714  1842  5766.516667  345991

# %% [markdown]
# Berdasarkan hasil di atas, bulan dengan rata-rata dan jumlah terbesar adalah Juni, sedangkan yang terkecil adalah Januari.

# %% [markdown]
# 2. Kelompok penyewa sepeda (baik casual dan registered) berdasarkan keadaan cuaca

# %%
day_df.groupby(by='weather_cond').agg({
    'count': ['max', 'min', 'mean', 'sum']
})
# Out:
#                     count
#                       max  min         mean      sum
# weather_cond
# Clear/Partly Cloudy  8714  431  4876.786177  2257952
# Light Snow/Rain      4639   22  1803.285714    37869
# Misty/Cloudy         8362  605  4035.862348   996858

# %% [markdown]
# Berdasarkan hasil di atas, penyewa sepeda lebih banyak menyewa saat cuaca cerah atau mendung, sangat sedikit saat salju, dan tidak ada penyewaan saat cuaca sangat buruk.

# %% [markdown]
# 3. Kelompok penyewa sepeda (baik casual dan registered) berdasarkan hari libur

# %%
day_df.groupby(by='holiday').agg({
    'count': ['max', 'min', 'mean', 'sum']
})
# Out:
#         count
#           max   min         mean      sum
# holiday
# 0        8714    22  4527.104225  3214244
# 1        7403  1000  3735.000000    78435

# %% [markdown]
# Berdasarkan hasil di atas, penyewa sepeda lebih suka menyewa pada hari-hari biasa dibandingkan hari libur.

# %% [markdown]
# 4. Bandingkan penyewa sepeda pada saat hari kerja (weekday) vs akhir pekan (weekend)

# %%
day_df.groupby(by='weekday').agg({
    'count':['max','min','mean']
})
# Out:
#         count
#           max   min         mean
# weekday
# Fri      8362  1167  4690.288462
# Mon      7525    22  4338.123810
# Sat      8714   627  4550.542857
# Sun      8227   605  4228.828571
# Thu      7804   431  4667.259615
# Tue      7767   683  4510.663462
# Wed      8173   441  4548.538462

# %% [markdown]
# Berdasarkan hasil diatas, Urutan rata-rata jumlah penyewa dari terbesar ke yang terkecil yakni: Jumat (Fri), Kamis (Thu), Sabtu (Sat), Rabu (Wed), Selasa (Tue), Senin (Mon), dan Minggu (Sun).

# %% [markdown]
# 5. Kelompokkan penyewa sepeda (baik casual dan registered) berdasarkan hari kerja

# %%
day_df.groupby(by='workingday').agg({
    'count': ['max', 'min', 'mean']
})
# Out:
#            count
#              max  min         mean
# workingday
# 0           8714  605  4330.168831
# 1           8362   22  4584.820000

# %% [markdown]
# Berdasarkan hasil diatas, jumlah penyewaan sepeda terbesar jatuh kepada workingday atau hari kerja dibandingkan dengan hari non-workingday. Namun dapat kita lihat juga, hasilnya lumayan berbeda walaupun tidak banyal.

# %% [markdown]
# 6. Kelompokkan penyewa sepeda (baik casual dan registered) berdasarkan season

# %%
day_df.groupby(by='season').agg({
    'casual': 'mean',
    'registered': 'mean',
    'count': ['max', 'min', 'mean']
})
# Out:
#              casual   registered count
#                mean         mean   max   min         mean
# season
# Fall    1202.611702  4441.691489  8714  1115  5644.303191
# Spring   334.928177  2269.204420  7836   431  2604.132597
# Summer  1106.097826  3886.233696  8362   795  4992.331522
# Winter   729.112360  3999.050562  8555    22  4728.162921

# %% [markdown]
# Berdasarkan analisis, penyewa sepeda, baik Casual maupun Registered, paling banyak menyewa di musim gugur (Fall) dengan rata-rata tertinggi, dan paling sedikit di musim semi (Spring) dengan rata-rata terendah.

# %% [markdown]
# 7. Kelompokkan temp, hum, dan humidity berdasarkan season

# %%
day_df.groupby(by='season').agg({
    'temp': ['max', 'min', 'mean'],
    'atemp': ['max', 'min', 'mean'],
    'hum': ['max', 'min', 'mean']
})
# Out:
#             temp                         atemp                           hum  \
#              max       min      mean       max       min      mean       max
# season
# Fall    0.861667  0.469167  0.706309  0.840896  0.242400  0.655898  0.939565
# Spring  0.572500  0.059130  0.297748  0.548617  0.079070  0.296914  0.948261
# Summer  0.808333  0.253043  0.544405  0.757579  0.250339  0.520307  0.922500
# Winter  0.657500  0.220833  0.422906  0.607975  0.227913  0.415539  0.972500
#
#
#              min      mean
# season
# Fall    0.360000  0.633482
# Spring  0.000000  0.582903
# Summer  0.254167  0.626948
# Winter  0.333478  0.668719

# %% [markdown]
# Berdasarkan analisis, dapat disimpulkan bahwa:
# - Rata-rata temperatur dan atemp tertinggi terjadi di musim gugur, diikuti oleh summer, winter, dan spring.
# - Rata-rata kelembapan tertinggi terjadi di musim dingin, diikuti oleh fall, summer, dan spring.

# %% [markdown]
# 8. Hubungan antara penyewa casual, registered, dan count

# %%
fig, ax = plt.subplots(figsize=(10,6))
correlation_matrix = day_df.corr(numeric_only=True)
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

sns.heatmap(
    correlation_matrix,
    annot=True,
    mask=mask,
    cmap="coolwarm",
    center=0,
    fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Berdasarkan analisis:
# - **Atemp** dan **temp** sangat berkorelasi (0.99).
# - **Hum** memiliki korelasi lemah dengan **temp** dan **atemp** (0.13 dan 0.14).
# - **Casual** cukup berkorelasi dengan **temp** dan **atemp** (0.54) dan sedikit negatif dengan **hum** (-0.08).
# - **Registered** memiliki pola serupa dengan **casual** dan berkorelasi moderat dengan **casual** (0.40).
# - **Count** berkorelasi kuat dengan **temp**, **atemp**, **casual**, dan **registered** (0.63, 0.63, 0.67, 0.95), dan sedikit negatif dengan **hum** (-0.10).

# %% [markdown]
# ## **Visualization & Explanatory Analysis**

# %% [markdown]
# ### **Pertanyaan 1: Apakah cuaca mempengaruhi jumlah orang yang menggunakan sepeda?**

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    x='weather_cond',
    y='count',
    data=day_df)

plt.title('Jumlah Pengguna Sepeda berdasarkan Kondisi Cuaca')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Jumlah Pengguna Sepeda')
plt.show()

# %% [markdown]
# Berdasarkan visualisasi data menggunakan boxplot, dapat disimpulkan bahwa terdapat hubungan antara kondisi cuaca dan penyewa sepeda. Cuaca cerah/setengah mendung menjadi yang paling diminati, diikuti oleh cuaca berkabut/mendung, sementara cuaca sedikit bersalju/hujan adalah yang paling sedikit diminati.

# %% [markdown]
# ### **Pertanyaan 2: Bagaimana perbedaan penggunaan sepeda pada hari kerja, hari libur, dan hari biasa?**

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(15,10))

# Berdasarkan workingday
sns.barplot(
    x='workingday',
    y='count',
    data=day_df,
    ax=axes[0])
axes[0].set_title('Jumlah Pengguna Sepeda berdasarkan Hari Kerja')
axes[0].set_xlabel('Hari Kerja')
axes[0].set_ylabel('Jumlah Pengguna Sepeda')

# Berdasarkan holiday
sns.barplot(
  x='holiday',
  y='count',
  data=day_df,
  ax=axes[1])
axes[1].set_title('Jumlah Pengguna Sepeda berdasarkan Hari Libur')
axes[1].set_xlabel('Hari Libur')
axes[1].set_ylabel('Jumlah Pengguna Sepeda')

# Berdasarkan weekday
sns.barplot(
  x='weekday',
  y='count',
  data=day_df,
  ax=axes[2])
axes[2].set_title('Jumlah Pengguna Sepeda berdasarkan Hari dalam Seminggu')
axes[2].set_xlabel('Hari dalam Seminggu')
axes[2].set_ylabel('Jumlah Pengguna Sepeda')

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan visualisasi data menggunakan barplot, dapat disimpulkan bahwa:
# - Jumlah penyewa sepeda lebih banyak pada hari kerja (Senin-Jumat) dibandingkan akhir pekan (Sabtu dan Minggu), dengan 0 untuk akhir pekan dan 1 untuk hari kerja.
# - Jumlah penyewa sepeda jauh lebih banyak pada hari biasa (bukan hari libur) dibandingkan hari libur nasional.
# - Jumlah penyewa sepeda terbanyak terjadi pada hari Jumat, sedangkan hari Minggu memiliki jumlah penyewa paling sedikit.

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# - **Kesimpulan Pertanyaan 1:** Terdapat hubungan jelas antara cuaca dan penyewa sepeda. Penyewa sangat menyukai cuaca Cerah/Sedikit mendung, dengan Q3 di atas 6000, Q1 di bawah 4000, dan median hampir 5000. Posisi kedua adalah cuaca Berkabut/Mendung, dengan Q3 di atas 5000, Q1 di bawah 3000, dan median di atas 4000. Pengguna kurang menyukai cuaca Sedikit bersalju/Hujan, dengan Q3 di atas 2000, Q1 di bawah 1000, dan median di atas 1000. Tidak ada data untuk cuaca Badai Besar, karena tidak memungkinkan untuk bersepeda.
#
# - **Kesimpulan Pertanyaan 2:** Visualisasi menunjukkan bahwa jumlah pengguna sepeda terbagi menjadi tiga bagian. Pada hari kerja, jumlah pengguna sedikit lebih tinggi dibandingkan non-hari kerja, meskipun perbedaannya tidak signifikan, keduanya di atas 4000. Pada hari libur, pengguna sepeda lebih banyak di non-holiday dibandingkan holiday. Ini menunjukkan bahwa pengguna lebih suka menyewa sepeda pada hari biasa. Berdasarkan weekday, hari Jumat memiliki rata-rata tertinggi (4690.29), sedangkan hari Minggu memiliki rata-rata terendah (4228.83).
